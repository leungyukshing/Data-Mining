# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('./final_GBM_01_450_7_14.csv')
print(file1)
# Out:
#                 Id  Predicted
# 0                1  -0.118048
# 1                2  -0.124956
# 2                3  -0.201719
# 3                4  -0.126393
# 4                5   0.009959
# 5                6   0.010538
# 6                7   0.006532
# 7                8  -0.020255
# 8                9  -0.026362
# 9               10  -0.325619
# 10              11  -0.118657
# 11              12  -0.117567
# 12              13  -0.227459
# 13              14  -0.152766
# 14              15  -0.162533
# 15              16  -0.177243
# 16              17  -0.186103
# 17              18  -0.154590
# 18              19  -0.300171
# 19              20  -0.406209
# 20              21  -0.249389
# 21              22  -0.173348
# 22              23  -0.157195
# 23              24  -0.113150
# 24              25   0.006482
# 25              26  -0.055864
# 26              27   0.425662
# 27              28   0.392329
# 28              29   0.382228
# 29              30  -0.304484
# ...

# %%
file2 = pd.read_csv('./final_RF_200.csv')
print(file2)
# Out:
#                 Id  Predicted
# 0                1  -0.098721
# 1                2  -0.102716
# 2                3  -0.199757
# 3                4  -0.107510
# 4                5   0.032910
# 5                6   0.014012
# 6                7   0.009429
# 7                8  -0.016467
# 8                9  -0.050790
# 9               10  -0.292073
# 10              11  -0.146648
# 11              12  -0.083228
# 12              13  -0.206213
# 13              14  -0.184565
# 14              15  -0.165688
# 15              16  -0.185683
# 16              17  -0.217522
# 17              18  -0.154080
# 18              19  -0.308365
# 19              20  -0.410182
# 20              21  -0.216591
# 21              22  -0.131255
# 22              23  -0.176444
# 23              24  -0.076094
# 24              25  -0.010567
# 25              26  -0.042553
# 26              27   0.387910
# 27              28   0.409705
# 28              29   0.353179
# 29              30  -0.278923
# ...

# %%
file3 = pd.read_csv('./final_RF_400.csv')
print(file3)
# Out:
#                 Id  Predicted
# 0                1  -0.089976
# 1                2  -0.073164
# 2                3  -0.189089
# 3                4  -0.102509
# 4                5   0.000227
# 5                6   0.018736
# 6                7  -0.009298
# 7                8  -0.021734
# 8                9  -0.033411
# 9               10  -0.303497
# 10              11  -0.148588
# 11              12  -0.111443
# 12              13  -0.208668
# 13              14  -0.192418
# 14              15  -0.184566
# 15              16  -0.196561
# 16              17  -0.189776
# 17              18  -0.140524
# 18              19  -0.314357
# 19              20  -0.400079
# 20              21  -0.224288
# 21              22  -0.140852
# 22              23  -0.207143
# 23              24  -0.081610
# 24              25  -0.014800
# 25              26  -0.024229
# 26              27   0.401799
# 27              28   0.409991
# 28              29   0.371466
# 29              30  -0.268286
# ...

# %%
file4 = pd.read_csv('./final_RF_400_4_15_4.csv')
print(file4)
# Out:
#                 Id  Predicted
# 0                1  -0.080857
# 1                2  -0.075294
# 2                3  -0.198794
# 3                4  -0.103774
# 4                5   0.017087
# 5                6   0.012394
# 6                7   0.004173
# 7                8  -0.020810
# 8                9  -0.044505
# 9               10  -0.302325
# 10              11  -0.144656
# 11              12  -0.111108
# 12              13  -0.211536
# 13              14  -0.169570
# 14              15  -0.185016
# 15              16  -0.188091
# 16              17  -0.201558
# 17              18  -0.141971
# 18              19  -0.290783
# 19              20  -0.396043
# 20              21  -0.221571
# 21              22  -0.138019
# 22              23  -0.172895
# 23              24  -0.069528
# 24              25  -0.013265
# 25              26  -0.036163
# 26              27   0.418774
# 27              28   0.462075
# 28              29   0.369511
# 29              30  -0.250646
# ...

# %%
temp = file1.add(file2)
temp = temp.add(file3)
temp = temp.add(file4)
temp = temp / 4
print(temp)
# Out:
#                 Id  Predicted
# 0                1  -0.096901
# 1                2  -0.094032
# 2                3  -0.197340
# 3                4  -0.110046
# 4                5   0.015046
# 5                6   0.013920
# 6                7   0.002709
# 7                8  -0.019816
# 8                9  -0.038767
# 9               10  -0.305878
# 10              11  -0.139637
# 11              12  -0.105837
# 12              13  -0.213469
# 13              14  -0.174830
# 14              15  -0.174451
# 15              16  -0.186894
# 16              17  -0.198740
# 17              18  -0.147791
# 18              19  -0.303419
# 19              20  -0.403128
# 20              21  -0.227960
# 21              22  -0.145868
# 22              23  -0.178419
# 23              24  -0.085096
# 24              25  -0.008038
# 25              26  -0.039702
# 26              27   0.408536
# 27              28   0.418525
# 28              29   0.369096
# 29              30  -0.275585
# ...

# %%
temp.to_csv('combine_result.csv', index=False)
